# %% [markdown]
# <div style="position: relative; max-width: 1350px; font-family: 'Times New Roman'; margin-bottom: 20px;">
#     <div style="background-color: #D35400; padding: 10px 20px 10px 30px; color: white; font-weight: bold; font-size: 1.3em; border-radius: 5px 20px 20px 5px; width: fit-content;">
#          Installation Plotly pour faire des graphiques interactifs en Python :
#     </div>
#     <div style="position: absolute; left: 0; top: 0; width: 10px; height: 100%; background-color: #F39C12; border-radius: 5px 0 0 5px;"></div>
# </div>

# %%
# !pip install plotly
# Out:
# ...
#   Using cached plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached plotly-6.7.0-py3-none-any.whl (9.9 MB)
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
